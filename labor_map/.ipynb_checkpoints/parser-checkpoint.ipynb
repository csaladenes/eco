# %%
import pandas as pd, json, requests

# %%
df=pd.read_excel('lmregtabli01february20217.xls',sheet_name='LI01',skiprows=6)

# %%
#https://data.gov.uk/dataset/24d87ad2-0fa9-4b35-816a-89f9d92b0042/local-authority-districts-april-2020-names-and-codes-in-the-united-kingdom
# http://geoportal1-ons.opendata.arcgis.com/datasets/fe6bcee87d95476abc84e194fe088abb_0.geojson
# http://geoportal1-ons.opendata.arcgis.com/datasets/fe6bcee87d95476abc84e194fe088abb_0.csv
#https://geoportal.statistics.gov.uk/search?collection=Dataset&sort=name&tags=all(BDY_LAD)

# %%
#Download shapefile
#BGC - larger detail
#BUG - small detail

# %%
#Mapshaper ->geojson, topojson export
#https://mapshaper.org/

# %%
topo=json.loads(open('geo/Local_Authority_Districts__April_2019__UK_BUC_v2.topo.json','r').read())

# %%
df.dropna()
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 6    E92000001                                            ENGLAND
# 7          NaN                                                NaN
# 8    E12000001                                         NORTH EAST
# 9          NaN                                                NaN
# 10   E06000047                                      County Durham
# ..         ...                                                ...
# 499        NaN                                  Quality indicator
# 500        NaN  Shaded Annual Population Survey estimates are ...
# 501        NaN  Unshaded Annual Population Survey estimates ar...
# 502        NaN                                                NaN
# 503        NaN  † - Annual Population Survey (APS) responses a...
#
#      16-64         (000s) Total            16+          (000s)  \
# 6              35116566.0                             27613477
# 7                     NaN                                  NaN
# 8               1660646.0                              1204462
# 9                     NaN                                  NaN
# 10               328496.0                               239930
# ..                    ...                                  ...
# 499                   NaN                                  NaN
# 500                   NaN                                  NaN
# 501                   NaN                                  NaN
# 502                   NaN                                  NaN
# 503                   NaN                                  NaN
#
#     16-64           Rate       (%) Total            16+          (000s).1  \
# 6                        75.964451                                1231634
# 7                              NaN                                    NaN
# 8                        71.481274                                  79731
# 9                              NaN                                    NaN
# 10                           71.88                                  13400
# ..                             ...                                    ...
# 499                            NaN                                    NaN
# 500                            NaN                                    NaN
# 501                            NaN                                    NaN
# 502                            NaN                                    NaN
# 503                            NaN                                    NaN
#
#     Rate4 (%) Total            16-64          (000s)  \
# 6    4.269819                                7176271
# 7         NaN                                    NaN
# 8    6.208646                                 387485
# 9         NaN                                    NaN
# 10        5.2                                  74911
# ..        ...                                    ...
# 499       NaN                                    NaN
# 500       NaN                                    NaN
# 501       NaN                                    NaN
# 502       NaN                                    NaN
# 503       NaN                                    NaN
#
#     16-64        Rate      (%)      Level  Proportion6      (%)  \
# 6                     20.56558  1594499.0              4.500000
# 7                          NaN        NaN                   NaN
# 8                    23.726365    97487.0              5.900000
# 9                          NaN        NaN                   NaN
# 10                   23.139676    17031.0              5.184538
# ..                         ...        ...                   ...
# 499                        NaN        NaN                   NaN
# 500                        NaN        NaN                   NaN
# 501                        NaN        NaN                   NaN
# 502                        NaN        NaN                   NaN
# 503                        NaN        NaN                   NaN
#
#      Total           (000s)  \
# 6                30999000.0
# 7                       NaN
# 8                 1224000.0
# 9                       NaN
# 10                 206000.0
# ..                      ...
# 499                     NaN
# 500                     NaN
# 501                     NaN
# 502                     NaN
# 503                     NaN
#
#     Jobs Density                                                        16-64                   (ratio)  \
# 6                                                 0.88
# 7                                                  NaN
# 8                                                 0.74
# 9                                                  NaN
# 10                                                0.63
# ..                                                 ...
# 499                                                NaN
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503                                                NaN
#
#     Resident\n(£) Workplace\n(£) Unnamed: 15
# 6           589.8          589.9         NaN
# 7             NaN            NaN         NaN
# 8           523.5          521.4  North East
# 9             NaN            NaN  North East
# 10          520.1          486.5  North East
# ..            ...            ...         ...
# 499           NaN            NaN         NaN
# 500           NaN            NaN         NaN
# 501           NaN            NaN         NaN
# 502           NaN            NaN         NaN
# 503           NaN            NaN         NaN
#
# [498 rows x 16 columns]
