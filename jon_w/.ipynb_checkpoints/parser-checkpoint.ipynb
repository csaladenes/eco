# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import altair as alt
import json

# %%
green='#36b7b4'
yellow='#f4c245'
pink='#e6224b'
grey='#666A86'

height=300
width=500

# %% [markdown]
# # Fig 1

# %% [markdown]
# ## a

# %%
df=pd.read_excel('excess1_ur.xls')
glyph='ur'
f='fig1a_unemployment'
f1a='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'ur', 'mean_ur', 'min_ur', 'max_ur', 'excess1_ur'], dtype='object')

# %%
ymin=2
ymax=7
base = alt.Chart(f1a,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('mean_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':2.2,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':2.5,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-05','y':6.3,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':2.8,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':2.6,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## b

# %% [markdown]
# # Fig 2

# %% [markdown]
# ## a

# %%
df=pd.read_excel('excess1_ft.xls')
glyph='ft'
f='fig2a_full_time_employment'
f2a='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'ft', 'm_ft', 'min_ft', 'max_ft', 'excess1_ft'], dtype='object')

# %%
ymin=70
ymax=80
base = alt.Chart(f2a,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':70.3,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':70.9,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-05','y':79,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':72,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':71.6,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## b

# %%
df=pd.read_excel('excess1_pt.xls')
glyph='pt'
f='fig2b_part_time_employment'
f2b='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'pt', 'm_pt', 'min_pt', 'max_pt', 'excess1_pt'], dtype='object')

# %%
ymin=20
ymax=30
base = alt.Chart(f2b,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':20.3,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':20.9,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-05','y':20.5,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':28,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':27.6,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## c

# %%
df=pd.read_excel('excess1_self.xls')
glyph='self'
f='fig2c_self_employment'
f2c='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'self', 'm_self', 'min_self', 'max_self',
#        'excess1_self'],
#       dtype='object')

# %%
ymin=10
ymax=18
base = alt.Chart(f2c,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':10.3,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':10.9,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-05','y':10.9,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':17.2,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':16.8,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## d

# %%
df=pd.read_excel('excess1_temp.xls')
glyph='temp'
f='fig2d_temp_employment'
f2d='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'temp', 'm_temp', 'min_temp', 'max_temp',
#        'excess1_temp'],
#       dtype='object')

# %%
ymin=2.5
ymax=7.5
base = alt.Chart(f2d,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':2.65,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':3.1,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-07-21','y':3.4,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-18','y':6.52,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-18','y':6.3,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Fig 3

# %%
df=pd.read_excel('excess1_rwpay_rpi.xls')
glyph='rwpay_rpi'
f='fig3_weekly_wage_levels'
f3='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df['max_rwpay_rpi']=500
df.columns
# Out:
# Index(['weekx', 'week3', 'rwpay_rpi', 'm_rwpay_rpi', 'min_rwpay_rpi',
#        'mmax_rwpay_rpi', 'max_rwpay_rpi'],
#       dtype='object')

# %%
ymin=400
ymax=580
base = alt.Chart(f3,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=26,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        tickCount=4,
                        titleFontWeight="normal",
                        titleAlign="left",
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':403,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':412,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-05','y':520,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':428,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':420,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Fig 4

# %%
df=pd.read_excel('excess1_ill.xls')
glyph='ill'
f='fig4_sickness_absence'
f4='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'ill', 'm_ill', 'min_ill', 'max_ill', 'excess1_ill'], dtype='object')

# %%
ymin=0
ymax=4
base = alt.Chart(f4,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':0.1,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':0.35,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-05','y':0.8,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':3.4,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':3.2,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Fig 5

# %%
df=pd.read_excel('excess1_away.xls')
glyph='away'
f='fig5_absent_from_work'
f5='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'away', 'm_away', 'min_away', 'max_away',
#        'excess1_away'],
#       dtype='object')

# %%
ymin=0
ymax=35
base = alt.Chart(f5,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':0.5,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':2.5,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-05','y':12,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':2.5,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-18','y':1,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q'),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Fig 6

# %%
df=pd.read_excel('excess1_nhoursx2.xls')
glyph='nhoursx2'
f='fig6_seasonal_work_hours'
f6='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df['max_nhoursx2']=1100
df.columns
# Out:
# Index(['weekx', 'week3', 'nhoursx2', 'm_nhoursx2', 'min_nhoursx2',
#        'mmax_nhoursx2', 'max_nhoursx2'],
#       dtype='object')

# %%
ymin=500
ymax=1200
base = alt.Chart(f6,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=31,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':515,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':550,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-07-28','y':810,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-30','y':605,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-30','y':570,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Fig 7

# %% [markdown]
# ## a

# %%
df=pd.read_excel('excess1_hired_week.xls')
glyph='hired_week'
f='fig7a_total_hires'
f7a='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'hired_week', 'm_hired_week', 'min_hired_week',
#        'max_hired_week', 'excess1_hired_week'],
#       dtype='object')

# %%
ymin=0
ymax=1.2
base = alt.Chart(f7a,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=26,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".1f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':0.03,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':0.1,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-07','y':0.42,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-05-07','y':1.07,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-05-07','y':1.015,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## b

# %%
df=pd.read_excel('excess1_hired_week_1624.xls')
glyph='hired_week_1624'
f='fig7b_youth_hires'
f7b='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'hired_week_1624', 'm_hired_week_1624',
#        'min_hired_week_1624', 'max_hired_week_1624',
#        'excess1_hired_week_1624'],
#       dtype='object')

# %%
ymin=0
ymax=5
base = alt.Chart(f7b,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':4.7,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':4.4,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-07','y':0.42,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-07','y':4.35,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-07','y':4.1,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Fig 8

# %% [markdown]
# ## a

# %%
df=pd.read_excel('excess1_red_week.xls')
glyph='red_week'
f='fig8a_layoffs'
f8a='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'red_week', 'm_red_week', 'min_red_week',
#        'max_red_week', 'excess1_red_week'],
#       dtype='object')

# %%
ymin=0
ymax=0.12
base = alt.Chart(f8a,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=31,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".2f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':0.11,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':0.103,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-03','y':0.103,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-07','y':0.01,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-09-07','y':0.004,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## b

# %%
df=pd.read_excel('excess1_quit_week.xls')
glyph='quit_week'
f='fig8b_quits'
f8b='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'quit_week', 'm_quit_week', 'min_quit_week',
#        'max_quit_week', 'excess1_quit_week'],
#       dtype='object')

# %%
ymin=0
ymax=0.35
base = alt.Chart(f8b,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=31,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=7,
                        format=".2f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':0.006,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':0.025,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-03','y':0.103,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-06-17','y':0.251,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-06-17','y':0.235,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Fig 9

# %%
df=pd.read_excel('excess1_move.xls')
glyph='move'
f='fig9_moves'
f9='https://raw.githubusercontent.com/csaladenes/eco-archive/main/jon_w/'+f+'.csv'
df.to_csv(f+'.csv')
df1=df.set_index('weekx')
df1.index=pd.to_datetime(df1.index)
df1.plot()
df.columns
# Out:
# Index(['weekx', 'week3', 'move', 'm_move', 'min_move', 'max_move',
#        'excess1_move'],
#       dtype='object')

# %%
ymin=0
ymax=4
base = alt.Chart(f9,title='').encode(
    alt.X('weekx:T',sort=[],
           axis=alt.Axis(grid=False,title=''))
).transform_calculate(
    max0="max(datum.max_"+glyph+",datum."+glyph+")"
).transform_calculate(
    min0="min(datum.min_"+glyph+",datum."+glyph+")"
)

marea = base.mark_area(opacity=0.15, color=grey).encode(
    alt.Y('max_'+glyph+':Q',
          axis=alt.Axis(title='percent',
                        domain=False,
                        ticks=False,
                        labelAlign="left",
                        labelBaseline="middle",
                        labelPadding=-5,
                        labelOffset=-10,
                        titleX=21,
                        titleY=-5,
                        titleAngle=0,
                        titleFontSize=10,
                        titleFontWeight="normal",
                        titleAlign="left",
                        tickCount=4,
                        format=".0f"),
         scale=alt.Scale(domain=[ymin, ymax])
         ),
    alt.Y2('min_'+glyph+':Q')
)                       
mline = base.mark_line(stroke=grey,strokeWidth=1).encode(
    alt.Y('m_'+glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)
area1 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('max0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('max_'+glyph+':Q')
)
area2 = base.mark_area(opacity=0.3, color=green).encode(
    alt.Y('min0:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Y2('min_'+glyph+':Q')
)
line = base.mark_line(stroke=green).encode(
    alt.Y(glyph+':Q',scale=alt.Scale(domain=[ymin, ymax]))
)

base = alt.Chart(pd.DataFrame([{'x':'2020-01-29'},{'x':'2020-03-18'}])).encode()
rule =base.mark_rule(stroke=grey,strokeWidth=1,strokeDash=[0,1,1],opacity=0.5).encode(
    alt.X('x:T')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-01-29','y':3.7,'text':'➡ First COVID-related death in the UK'},
                               {'x':'2020-03-18','y':3.45,'text':'➡ Start of first UK lockdown'}])).encode()
rlabels =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-10-03','y':0.15,'text':'2020'}])).encode()
mlabel =base.mark_text(fontWeight='bold',color=green,align='left',baseline='bottom',fontSize=11).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N',)
)
base = alt.Chart(pd.DataFrame([{'x':'2020-06-17','y':2.4,'text':'2014-2019 average'}])).encode()
label1 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
base = alt.Chart(pd.DataFrame([{'x':'2020-06-17','y':2.2,'text':'and min-max range'}])).encode()
label2 =base.mark_text(fontWeight='lighter',color=grey,align='left',baseline='bottom',fontSize=10,opacity=0.5).encode(
    alt.X('x:T'),
    alt.Y('y:Q',scale=alt.Scale(domain=[ymin, ymax])),
    alt.Text('text:N')
)
layer1=alt.layer(rule, rlabels, 
                 marea,mline,
                 area1,area2,line,
                 mlabel,label1,label2).configure_view(
        height=height,
        width=width,
    )
layer1.save(f+'.json')
layer1
# Out:
# alt.LayerChart(...)
